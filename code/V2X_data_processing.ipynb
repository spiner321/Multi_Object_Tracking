# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # # 데이터 전처리
# ---

# %%
df = pd.read_csv('/data/NIA50/50-1/data/Sejong/0901_5RNBVU80.csv')
df.loc[df['scene'].]
# Out:
#                 ISSUE_DATE  VEHICLE_CLASS  VEHICLE_TYPE           X  \
# 0      2022-09-01 08:54:26         9220.0           4.0  127.393805
# 1      2022-09-01 08:54:27         9220.0           4.0  127.393509
# 2      2022-09-01 08:54:28         9220.0           4.0  127.393214
# 3      2022-09-01 08:54:29         9220.0           4.0  127.392864
# 4      2022-09-01 08:54:50         9220.0           4.0  127.386428
# ...                    ...            ...           ...         ...
# 13319  2022-09-01 14:32:35         9220.0           4.0  127.390315
# 13320  2022-09-01 14:32:36         9220.0           4.0  127.390614
# 13321  2022-09-01 14:32:37         9220.0           4.0  127.390903
# 13322  2022-09-01 14:32:38         9220.0           4.0  127.391184
# 13323  2022-09-01 14:32:39         9220.0           4.0  127.391184
#
#                Y  HEADING  SPEED  HAZARDLIGHTS_FLAG  HARDBRAKING_FLAG  \
# 0      36.410704      NaN    NaN                NaN               NaN
# ...

# %%
# (samples, features, time)
scenes.value_counts()[scenes.value_counts() < 10]
# Out:
# scene_4    4
# Name: scene, dtype: int64
