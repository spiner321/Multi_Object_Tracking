# %% [markdown]
# # # DeepfusionMOT 설치
# ---

# %%
# DeepfusionMOT 설치

# %cd /content/drive/MyDrive/workspace/study/3D_Object_detection
# !git clone https://github.com/wangxiyang2022/DeepFusionMOT

# %%
# 필요 모듈 설치

# %cd /data/NIA50/50-2/models/DeepFusionMOT
# !pip install -r requirements.txt

# %% [markdown]
# # # MOT 실행
# ---
# - CUDA_VISIBLE_DEVICES=3 pm2 start main.py --interpreter python --name "deepfusionmot_integ_test" --no-autorestart -- --data-root /data/NIA50/50-2/data/nia50_final/deepfusionmot_integ --detections3D 3D_pvrcnn --detections2D 2D_yolov5 --save-root /data/NIA50/50-2/result/deepfusionmot_integ --save-img

# %%
# 디텍팅
# main.py와 visualization에서 경로 수정 필수

# %cd /data/NIA50/50-2/models/DeepFusionMOT
# !python main.py

# %%
# %cd /data/NIA50/50-2/models/DeepFusionMOT_aivill

data_root = '/data/NIA50/50-2/data/nia50_final/deepfusionmot_integ_final_testset2'
detections_3D = '3D_pvrcnn'
detections_2D = '2D_yolov5'
save_root = '/data/NIA50/50-2/result/deepfusionmot_integ_final_testset2_'

# !python main.py --data-root {data_root} --detections3D {detections_3D} --detections2D {detections_2D} --save-root {save_root} --save-img
# Out:
# /data/NIA50/50-2/models/DeepFusionMOT_aivill
# --------------Start processing the L_2210_Suwon_A_N_C0197 dataset--------------
# /data/NIA50/50-2/models/DeepFusionMOT_aivill/tracking/cost_function.py:32: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, C))
#   return 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))
# --------------The time it takes to process all datasets are 1.30084228515625s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0198 dataset--------------
# --------------The time it takes to process all datasets are 1.4889483451843262s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0199 dataset--------------
# --------------The time it takes to process all datasets are 1.7083537578582764s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0378 dataset--------------
# ...

# %%
# %cd /data/NIA50/50-2/models/DeepFusionMOT_aivill

data_root = '/data/NIA50/50-2/data/nia50_final/deepfusionmot_integ_2'
detections_3D = '3D_pvrcnn'
detections_2D = '2D_yolov5'
save_root = '/data/NIA50/50-2/result/deepfusionmot_integ_2-1'

f'python main.py --data-root {data_root} --detections3D {detections_3D} --detections2D {detections_2D} --save-root {save_root} --save-img'
# Out:
# /data/NIA50/50-2/models/DeepFusionMOT_aivill
# 'python main.py --data-root /data/NIA50/50-2/data/nia50_final/deepfusionmot_integ_2 --detections3D 3D_pvrcnn --detections2D 2D_yolov5 --save-root /data/NIA50/50-2/result/deepfusionmot_integ_2-1 --save-img'

# %%
# %cd /data/NIA50/50-2/models/DeepFusionMOT_aivill

data_root = '/data/NIA50/50-2/data/nia50_final/deepfusionmot_integ_2'
detections_3D = '3D_pvrcnn'
detections_2D = '2D_yolov5'
save_root = '/data/NIA50/50-2/result/deepfusionmot_integ_2-1'

# !python main.py --data-root {data_root} --detections3D {detections_3D} --detections2D {detections_2D} --save-root {save_root} --save-img
# Out:
# /data/NIA50/50-2/models/DeepFusionMOT_aivill
# --------------Start processing the L_2210_Suwon_A_N_C0198 dataset--------------
# --------------The time it takes to process all datasets are 1.3974735736846924s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0199 dataset--------------
# ^C
# Traceback (most recent call last):
#   File "/data/NIA50/50-2/models/DeepFusionMOT_aivill/main.py", line 261, in <module>
#     show_image_with_boxes(img_0, bbox3d_tmp, image_path, color, img0_name, label, calib_file_seq,line_thickness=1)
#   File "/data/NIA50/50-2/models/DeepFusionMOT_aivill/visualization/visualization_3d.py", line 58, in show_image_with_boxes
#     cv2.imwrite(image_path + "/" + "{}.jpg".format(img0_name), img2)
# KeyboardInterrupt

# %%
# %cd /NIA50/50-2/models/DeepFusionMOT

# !python main.py --help

# %% [markdown]
# # # 결과물 영상화
# ---

# %%
# 디텍팅 결과 영상 생성
# img_to_video.py 수정 필수

# %cd /content/drive/MyDrive/workspace/study/3D_Object_detection/DeepFusionMOT/visualization
# !python img_to_video.py
