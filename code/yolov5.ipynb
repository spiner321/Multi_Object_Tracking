# %%
import os
import glob
import torch
import gc

# %% [markdown]
# # # yolov5
# ---

# %% [markdown]
# ## # yolov5 가져오기
# ---

# %%
# %cd /content/drive/MyDrive/workspace/study/3D_Object_detection
# !git clone https://github.com/ultralytics/yolov5

# %% [markdown]
# ## # 모듈 임포트
# ---

# %%
# %cd /data/NIA50/50-2/models/yolov5
# !pip install -r requirements.txt  # install

# %% [markdown]
# ## # 사전학습된 모델 다운로드
# ---

# %%
import torch

# 사전 학습된 모델 뽑아내기
model = torch.hub.load('ultralytics/yolov5', 'yolov5l6')  # or yolov5n, yolov5x6, custom

# %% [markdown]
# ## # 데이터에 맞춰 yaml 생성
# ---

# %%
import glob
from sklearn.model_selection import train_test_split

img_list = sorted(glob.glob('/data/NIA50/data/2-050_sensor_sample/camera/front/images/*.jpg'))

# train_temp, test_list = train_test_split(img_list, test_size = 0.2, random_state = 0)

# train_list, val_list = train_test_split(train_temp, test_size = 0.2, random_state = 0)

train_list, val_list = train_test_split(img_list, test_size = 0.8, random_state = 0)


with open('/data/NIA50/yolov5/nia50/train.txt', 'w') as f:
    f.write('\n'.join(train_list) + '\n')
    
with open('/data/NIA50/yolov5/nia50/val.txt', 'w') as f:
    f.write('\n'.join(val_list) + '\n')
    
# with open('/data/NIA50/yolov5/nia50/test.txt', 'w') as f:
#     f.write('\n'.join(test_list) + '\n')
    
# with open('')

# %% [markdown]
# ## # cuda 확인
# ---

# %%
# gpu 캐시 삭제

import gc
gc.collect()
torch.cuda.empty_cache()

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())

# %%
torch.cuda.get_device_name(0)

# %%
# gpu 할당

import os
import torch

os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0, 1' # gpu 여러개 할당

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## # 훈련
# ---

# %%
# 훈련

# %cd /home/ubuntu/kimgh/yolov5
# !python train.py --img 640 --batch 16 --epochs 3 --data ./data/kitti.yaml --cfg ./models/yolov5x_kitti.yaml --weights yolov5x.pt --optimizer Adam --name kitti_result

# %%
# %cd /data/NIA50/yolov5
# !python train.py --img 1280 --batch 16 --epochs 5 --data ./nia50/nia50.yaml --cfg ./nia50/yolov5l6.yaml --weights ./ckpt/yolov5l6.pt --optimizer Adam --name sample_result

# %%
# NIA50_train_1st
# %cd /data/NIA50/50-2/models/yolov5

data = '/data/NIA50/50-2/data/NIA50/train_1st/yolov5/nia50_train1st_data_yolov5l6.yaml'
model = '/data/NIA50/50-2/data/NIA50/train_1st/yolov5/nia50_train1st_model_yolov5l6.yaml'
# weights = '/data/NIA50/50-2/models/yolov5/runs/train/nia50_train1st2/weights/last.pt'
weights = '/data/NIA50/50-2/models/yolov5/ckpt/yolov5l6.pt'
name = 'nia50_train1st'

# !python train.py --img 1200 --batch 12 --epochs 100 --data {data} --cfg {model} --weights {weights} --optimizer AdamW --name {name} --device 2,3

# %%
# NIA50_train_1st
# %cd /data/NIA50/50-2/models/yolov5

data = '/data/NIA50/50-2/data/NIA50/train_1st/yolov5/nia50_train1st_data_yolov5l6.yaml'
model = '/data/NIA50/50-2/data/NIA50/train_1st/yolov5/nia50_train1st_model_yolov5l6.yaml'
weights = '/data/NIA50/50-2/models/yolov5/runs/train/nia50_train1st/weights/best.pt'
name = 'nia50_train1st'

# !python train.py --img 1200 --batch 16 --epochs 20 --data {data} --cfg {model} --weights {weights} --optimizer AdamW --name {name} --device 0,1,2,3

# %%
# %cd /data/NIA50/yolov5

data = '/data/NIA50/yolov5/nia50/yolo_aivill48/data_yolo_aivill48.yaml'
model = '/data/NIA50/yolov5/nia50/yolo_aivill48/model_yolov5l6.yaml'
weights = '/data/NIA50/yolov5/ckpt/yolov5l6.pt'

# !python train.py --img 640 --batch 15 --epochs 100 --data {data} --cfg {model} --weights {weights} --optimizer AdamW --name yolo_avill48_re --device 1,2

# %%
# temp_data
# %cd /data/NIA50/50-2/models/yolov5

data = '/data/NIA50/50-2/data/NIA48/temp_data/temp_data_data_yolo5l6.yaml'
model = '/data/NIA50/50-2/data/NIA48/temp_data/temp_data_cfg_yolov5l6.yaml' # cfg
weights = '/data/NIA50/50-2/models/yolov5/ckpt/yolov5l6.pt'

# !python train.py --img 1200 --batch 15 --epochs 100 --data {data} --cfg {model} --weights {weights} --optimizer AdamW --name temp_data --device 1,2,3

# %%
# %cd /data/NIA50/50-2/models/yolov5

# !python train.py --help

# %% [markdown]
# ## # 검증
# ---

# %%
# 검증

# %cd /home/ubuntu/kimgh/yolov5
# !python val.py --weights ./runs/train/kitti_result3/weights/best.pt --data ./data/kitti.yaml --img 640

# %%
# %cd /data/NIA50/yolov5
# !python val.py --data ./nia50/nia50.yaml --weights ./ckpt/yolov5l6.pt --batch-size 15 --img 1280 --verbose --name sample_val --save-txt --save-conf --exist-ok --device 0,1,2

# %%
# %cd /data/NIA50/50-2/models/yolov5

data = '/data/NIA50/50-2/data/NIA50/train_1st/yolov5/nia50_train1st_data_yolov5l6.yaml'
# model = '/data/NIA50/yolov5/nia50/yolo_aivill48/model_yolov5l6.yaml'
weights = '/data/NIA50/50-2/models/yolov5/runs/train/nia50_train1st3/weights/best.pt'
name = 'nia50_train1st'

# !python val.py --data {data} --weights {weights} --batch-size 16 --img 1200 --verbose --name {name} --single-cls --save-txt --save-conf --save-json --exist-ok --device 0,1,2,3

# %%
# %cd /data/NIA50/50-2/models/yolov5

# !python val.py --help

# %% [markdown]
# ## # 테스트
# ---

# %%
# %cd /data/NIA50/50-2/models/yolov5

import os
import glob

scenes = sorted(os.listdir('/data/NIA50/50-2/data/NIA50/학습용데이터_pre4/Suwon/labels'))
scenes = sorted(list(set([i[:-9] for i in scenes])))

data = 'data/nia50_data_yolov5l6.yaml'
# model = 'data/nia50_model_yolov5l6.yaml'
weights = '/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'
img_size = '1200 1920'
project = 'runs/nia50_train1st'

for scene in scenes[1:]:
    source = f'/data/NIA50/50-2/data/NIA50/train_1st/raw/{scene}/camera/camera_0'
    # !python detect.py --weights {weights} --data {data} --img {img_size} --conf 0.4 --project {project} --source {source} --name {scene} \
        --save-txt --save-conf --exist-ok --nosave --device 0,1,2,3
# Out:
# /data/NIA50/50-2/models/yolov5
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0039, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0000.jpg: 1216x1920 2 Small_Cars, 2 Cars, 2 SUVs, 4 Adults, 148.8ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0001.jpg: 1216x1920 2 Small_Cars, 2 Cars, 1 SUV, 5 Adults, 142.3ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0002.jpg: 1216x1920 2 Small_Cars, 2 Cars, 2 SUVs, 5 Adults, 143.7ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0003.jpg: 1216x1920 2 Small_Cars, 2 Cars, 2 SUVs, 1 Two_Wheeler, 6 Adults, 144.0ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0004.jpg: 1216x1920 2 Small_Cars, 2 Cars, 4 SUVs, 6 Adults, 143.7ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0005.jpg: 1216x1920 4 Small_Cars, 3 Cars, 2 SUVs, 1 Small_Truck, 8 Adults, 141.5ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0006.jpg: 1216x1920 3 Small_Cars, 5 Cars, 4 SUVs, 9 Adults, 142.6ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0007.jpg: 1216x1920 2 Small_Cars, 5 Cars, 1 Van, 1 SUV, 9 Adults, 145.5ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0008.jpg: 1216x1920 2 Small_Cars, 5 Cars, 1 Van, 2 SUVs, 10 Adults, 141.5ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0039/camera/camera_0/0009.jpg: 1216x1920 2 Small_Cars, 4 Cars, 1 Van, 2 SUVs, 10 Adults, 144.9ms
# Speed: 2.2ms pre-process, 143.9ms inference, 1.8ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0039
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0039/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0062, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0000.jpg: 1216x1920 6 Cars, 1 Van, 1 Kickboard, 8 Adults, 153.7ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0001.jpg: 1216x1920 8 Cars, 1 Van, 1 Two_Wheeler, 1 Kickboard, 10 Adults, 142.5ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0002.jpg: 1216x1920 5 Cars, 2 SUVs, 1 Two_Wheeler, 1 Kickboard, 8 Adults, 142.1ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0003.jpg: 1216x1920 5 Cars, 1 Van, 1 Small_Truck, 12 Adults, 143.7ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0004.jpg: 1216x1920 6 Cars, 1 Van, 2 SUVs, 1 Small_Truck, 1 Medium_Truck, 1 Kickboard, 10 Adults, 141.8ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0005.jpg: 1216x1920 2 Cars, 1 Van, 2 SUVs, 1 Small_Truck, 1 Kickboard, 10 Adults, 143.6ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0006.jpg: 1216x1920 1 Small_Car, 2 Cars, 1 Van, 2 SUVs, 1 Small_Truck, 1 Kickboard, 12 Adults, 143.1ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0007.jpg: 1216x1920 2 Small_Cars, 1 Light_Car, 2 Cars, 1 Van, 2 SUVs, 1 Kickboard, 10 Adults, 142.9ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0008.jpg: 1216x1920 1 Small_Car, 1 Light_Car, 4 Cars, 1 Van, 2 SUVs, 1 Kickboard, 10 Adults, 141.4ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0062/camera/camera_0/0009.jpg: 1216x1920 1 Small_Car, 1 Light_Car, 4 Cars, 2 Vans, 1 SUV, 12 Adults, 144.9ms
# Speed: 2.2ms pre-process, 144.0ms inference, 1.7ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0062
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0062/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0069, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0000.jpg: 1216x1920 1 Light_Car, 4 Cars, 1 Van, 1 SUV, 1 Bus, 3 Adults, 148.6ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0001.jpg: 1216x1920 1 Light_Car, 3 Cars, 1 Van, 3 SUVs, 3 Adults, 142.8ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0002.jpg: 1216x1920 1 Light_Car, 4 Cars, 2 SUVs, 3 Adults, 142.3ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0003.jpg: 1216x1920 1 Light_Car, 4 Cars, 2 SUVs, 3 Adults, 143.1ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0004.jpg: 1216x1920 1 Light_Car, 4 Cars, 2 SUVs, 3 Adults, 142.5ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0005.jpg: 1216x1920 1 Light_Car, 4 Cars, 2 SUVs, 3 Adults, 143.2ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0006.jpg: 1216x1920 1 Light_Car, 5 Cars, 2 SUVs, 1 Two_Wheeler, 4 Adults, 142.1ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0007.jpg: 1216x1920 2 Light_Cars, 4 Cars, 1 SUV, 1 Two_Wheeler, 4 Adults, 141.9ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0008.jpg: 1216x1920 2 Light_Cars, 3 Cars, 1 SUV, 4 Adults, 143.3ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0069/camera/camera_0/0009.jpg: 1216x1920 1 Light_Car, 5 Cars, 1 SUV, 4 Adults, 142.1ms
# Speed: 2.0ms pre-process, 143.2ms inference, 1.6ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0069
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0069/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0101, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0000.jpg: 1216x1920 1 Car, 1 Bus, 4 Adults, 149.3ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0001.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 142.1ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0002.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 142.5ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0003.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 143.8ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0004.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 141.9ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0005.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 141.5ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0006.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 142.9ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0007.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 143.0ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0008.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 142.3ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0101/camera/camera_0/0009.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 146.3ms
# Speed: 2.0ms pre-process, 143.6ms inference, 1.8ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0101
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0101/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0102, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0000.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 155.8ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0001.jpg: 1216x1920 2 Cars, 2 Buss, 4 Adults, 143.0ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0002.jpg: 1216x1920 2 Cars, 1 Bus, 4 Adults, 145.1ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0003.jpg: 1216x1920 3 Cars, 1 Bus, 4 Adults, 142.7ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0004.jpg: 1216x1920 3 Cars, 1 Bus, 4 Adults, 144.2ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0005.jpg: 1216x1920 3 Cars, 1 Bus, 4 Adults, 143.7ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0006.jpg: 1216x1920 4 Cars, 1 Bus, 4 Adults, 141.9ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0007.jpg: 1216x1920 3 Cars, 1 SUV, 1 Bus, 5 Adults, 142.6ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0008.jpg: 1216x1920 4 Cars, 1 SUV, 1 Bus, 6 Adults, 144.2ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0102/camera/camera_0/0009.jpg: 1216x1920 4 Cars, 1 Bus, 7 Adults, 142.8ms
# Speed: 2.2ms pre-process, 144.6ms inference, 1.6ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0102
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0102/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0103, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0000.jpg: 1216x1920 3 Cars, 1 Bus, 7 Adults, 154.6ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0001.jpg: 1216x1920 3 Cars, 1 SUV, 1 Bus, 7 Adults, 144.1ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0002.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 142.8ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0003.jpg: 1216x1920 4 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 145.7ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0004.jpg: 1216x1920 4 Cars, 1 Bus, 2 Two_Wheelers, 7 Adults, 142.9ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0005.jpg: 1216x1920 5 Cars, 1 Bus, 2 Two_Wheelers, 7 Adults, 142.4ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0006.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 142.7ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0007.jpg: 1216x1920 1 Light_Car, 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 143.3ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0008.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 144.4ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0103/camera/camera_0/0009.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 127.0ms
# Speed: 2.2ms pre-process, 143.0ms inference, 1.4ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0103
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0103/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0104, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0000.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 159.1ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0001.jpg: 1216x1920 1 Small_Car, 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 142.5ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0002.jpg: 1216x1920 1 Small_Car, 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 146.3ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0003.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 143.5ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0004.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 144.4ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0005.jpg: 1216x1920 5 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 144.2ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0006.jpg: 1216x1920 6 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 142.1ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0007.jpg: 1216x1920 6 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 144.4ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0008.jpg: 1216x1920 8 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 143.2ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0104/camera/camera_0/0009.jpg: 1216x1920 8 Cars, 1 Two_Wheeler, 7 Adults, 143.8ms
# Speed: 2.2ms pre-process, 145.4ms inference, 1.5ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0104
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0104/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0105, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0000.jpg: 1216x1920 10 Cars, 1 Bus, 1 Two_Wheeler, 7 Adults, 158.0ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0001.jpg: 1216x1920 9 Cars, 1 Van, 1 Bus, 1 Two_Wheeler, 6 Adults, 143.1ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0002.jpg: 1216x1920 7 Cars, 1 Van, 1 Bus, 1 Two_Wheeler, 6 Adults, 143.9ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0003.jpg: 1216x1920 6 Cars, 1 Van, 1 Two_Wheeler, 7 Adults, 146.4ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0004.jpg: 1216x1920 7 Cars, 1 Van, 1 Two_Wheeler, 10 Adults, 142.9ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0005.jpg: 1216x1920 6 Cars, 1 Two_Wheeler, 10 Adults, 146.0ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0006.jpg: 1216x1920 7 Cars, 1 Van, 1 Two_Wheeler, 10 Adults, 145.3ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0007.jpg: 1216x1920 7 Cars, 1 SUV, 1 Two_Wheeler, 9 Adults, 147.5ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0008.jpg: 1216x1920 8 Cars, 1 Van, 1 SUV, 1 Two_Wheeler, 9 Adults, 142.6ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0105/camera/camera_0/0009.jpg: 1216x1920 8 Cars, 1 Van, 1 Two_Wheeler, 8 Adults, 142.6ms
# Speed: 2.1ms pre-process, 145.8ms inference, 1.6ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0105
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0105/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0106, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0000.jpg: 1216x1920 8 Cars, 1 Two_Wheeler, 9 Adults, 152.2ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0001.jpg: 1216x1920 10 Cars, 1 Bus, 1 Two_Wheeler, 9 Adults, 144.8ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0002.jpg: 1216x1920 11 Cars, 1 Bus, 1 Two_Wheeler, 9 Adults, 144.1ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0003.jpg: 1216x1920 12 Cars, 1 Bus, 1 Two_Wheeler, 8 Adults, 143.7ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0004.jpg: 1216x1920 13 Cars, 1 Bus, 1 Two_Wheeler, 9 Adults, 142.7ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0005.jpg: 1216x1920 13 Cars, 1 SUV, 1 Bus, 1 Two_Wheeler, 9 Adults, 142.7ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0006.jpg: 1216x1920 12 Cars, 1 Two_Wheeler, 9 Adults, 143.3ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0007.jpg: 1216x1920 12 Cars, 1 Bus, 1 Two_Wheeler, 9 Adults, 143.8ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0008.jpg: 1216x1920 13 Cars, 1 SUV, 1 Bus, 1 Two_Wheeler, 9 Adults, 143.8ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0106/camera/camera_0/0009.jpg: 1216x1920 11 Cars, 1 SUV, 1 Bus, 1 Two_Wheeler, 9 Adults, 146.9ms
# Speed: 2.1ms pre-process, 144.8ms inference, 1.5ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0106
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0106/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0107, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0000.jpg: 1216x1920 2 Small_Cars, 2 Light_Cars, 10 Cars, 1 Van, 1 Bus, 1 Two_Wheeler, 10 Adults, 165.2ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0001.jpg: 1216x1920 3 Small_Cars, 7 Cars, 1 Two_Wheeler, 10 Adults, 142.3ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0002.jpg: 1216x1920 4 Small_Cars, 1 Light_Car, 7 Cars, 1 Two_Wheeler, 10 Adults, 144.1ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0003.jpg: 1216x1920 4 Small_Cars, 8 Cars, 1 Two_Wheeler, 9 Adults, 145.3ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0004.jpg: 1216x1920 4 Small_Cars, 7 Cars, 1 SUV, 1 Two_Wheeler, 9 Adults, 146.7ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0005.jpg: 1216x1920 4 Small_Cars, 7 Cars, 1 SUV, 1 Two_Wheeler, 10 Adults, 145.1ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0006.jpg: 1216x1920 3 Small_Cars, 8 Cars, 1 SUV, 1 Two_Wheeler, 9 Adults, 144.5ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0007.jpg: 1216x1920 3 Small_Cars, 1 Light_Car, 9 Cars, 1 Bus, 1 Two_Wheeler, 10 Adults, 142.8ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0008.jpg: 1216x1920 2 Small_Cars, 9 Cars, 1 Van, 1 Bus, 1 Two_Wheeler, 10 Adults, 143.3ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0107/camera/camera_0/0009.jpg: 1216x1920 2 Small_Cars, 1 Light_Car, 8 Cars, 1 SUV, 1 Bus, 1 Two_Wheeler, 10 Adults, 142.5ms
# Speed: 2.1ms pre-process, 146.2ms inference, 1.8ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0107
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0107/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0108, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0000.jpg: 1216x1920 2 Light_Cars, 8 Cars, 2 SUVs, 1 Two_Wheeler, 10 Adults, 159.3ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0001.jpg: 1216x1920 2 Light_Cars, 10 Cars, 1 SUV, 1 Two_Wheeler, 10 Adults, 143.6ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0002.jpg: 1216x1920 3 Light_Cars, 9 Cars, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 10 Adults, 143.2ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0003.jpg: 1216x1920 3 Light_Cars, 6 Cars, 1 SUV, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 145.1ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0004.jpg: 1216x1920 3 Light_Cars, 5 Cars, 2 SUVs, 1 Small_Truck, 1 Two_Wheeler, 9 Adults, 143.4ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0005.jpg: 1216x1920 3 Light_Cars, 6 Cars, 2 SUVs, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 144.5ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0006.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 7 Cars, 3 SUVs, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 145.2ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0007.jpg: 1216x1920 2 Light_Cars, 4 Cars, 3 SUVs, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 143.8ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0008.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 6 Cars, 2 SUVs, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 144.4ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0108/camera/camera_0/0009.jpg: 1216x1920 2 Small_Cars, 4 Light_Cars, 6 Cars, 2 SUVs, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 142.6ms
# Speed: 2.1ms pre-process, 145.5ms inference, 1.6ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0108
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0108/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0109, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0000.jpg: 1216x1920 2 Small_Cars, 3 Light_Cars, 7 Cars, 3 SUVs, 1 Two_Wheeler, 10 Adults, 147.6ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0001.jpg: 1216x1920 4 Light_Cars, 6 Cars, 4 SUVs, 1 Two_Wheeler, 10 Adults, 143.6ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0002.jpg: 1216x1920 1 Small_Car, 3 Light_Cars, 5 Cars, 3 SUVs, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 143.1ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0003.jpg: 1216x1920 1 Small_Car, 3 Light_Cars, 6 Cars, 3 SUVs, 1 Two_Wheeler, 10 Adults, 143.6ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0004.jpg: 1216x1920 1 Small_Car, 3 Light_Cars, 7 Cars, 3 SUVs, 1 Two_Wheeler, 10 Adults, 143.9ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0005.jpg: 1216x1920 1 Small_Car, 4 Light_Cars, 7 Cars, 3 SUVs, 1 Two_Wheeler, 10 Adults, 146.8ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0006.jpg: 1216x1920 3 Light_Cars, 6 Cars, 3 SUVs, 1 Small_Truck, 1 Two_Wheeler, 10 Adults, 143.6ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0007.jpg: 1216x1920 2 Light_Cars, 5 Cars, 3 SUVs, 1 Two_Wheeler, 10 Adults, 142.4ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0008.jpg: 1216x1920 2 Light_Cars, 5 Cars, 4 SUVs, 1 Two_Wheeler, 10 Adults, 145.5ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0109/camera/camera_0/0009.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 6 Cars, 3 SUVs, 1 Two_Wheeler, 10 Adults, 144.5ms
# Speed: 2.0ms pre-process, 144.5ms inference, 1.6ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0109
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0109/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0110, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0000.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 5 Cars, 1 Van, 1 SUV, 1 Two_Wheeler, 11 Adults, 149.9ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0001.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 7 Cars, 1 Van, 1 Two_Wheeler, 11 Adults, 143.7ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0002.jpg: 1216x1920 2 Light_Cars, 7 Cars, 1 Van, 1 Two_Wheeler, 11 Adults, 143.3ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0003.jpg: 1216x1920 2 Light_Cars, 7 Cars, 1 Van, 1 Two_Wheeler, 11 Adults, 145.9ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0004.jpg: 1216x1920 2 Light_Cars, 6 Cars, 1 Two_Wheeler, 10 Adults, 147.9ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0005.jpg: 1216x1920 3 Light_Cars, 6 Cars, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 12 Adults, 144.7ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0006.jpg: 1216x1920 3 Light_Cars, 5 Cars, 1 Medium_Truck, 1 Two_Wheeler, 13 Adults, 143.3ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0007.jpg: 1216x1920 3 Light_Cars, 9 Cars, 1 Small_Truck, 1 Medium_Truck, 1 Two_Wheeler, 13 Adults, 145.7ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0008.jpg: 1216x1920 2 Small_Cars, 3 Light_Cars, 6 Cars, 1 SUV, 1 Two_Wheeler, 13 Adults, 143.1ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0110/camera/camera_0/0009.jpg: 1216x1920 3 Light_Cars, 7 Cars, 1 Van, 1 Medium_Truck, 1 Bus, 1 Two_Wheeler, 14 Adults, 145.1ms
# Speed: 2.1ms pre-process, 145.2ms inference, 1.7ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0110
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0110/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0111, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0000.jpg: 1216x1920 3 Light_Cars, 7 Cars, 1 Van, 2 Two_Wheelers, 12 Adults, 160.2ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0001.jpg: 1216x1920 3 Light_Cars, 7 Cars, 1 Van, 2 Two_Wheelers, 12 Adults, 146.3ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0002.jpg: 1216x1920 3 Light_Cars, 8 Cars, 1 Bus, 2 Two_Wheelers, 15 Adults, 143.8ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0003.jpg: 1216x1920 3 Light_Cars, 8 Cars, 1 Bus, 2 Two_Wheelers, 14 Adults, 142.2ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0004.jpg: 1216x1920 3 Light_Cars, 8 Cars, 1 Bus, 1 Two_Wheeler, 12 Adults, 144.1ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0005.jpg: 1216x1920 3 Light_Cars, 8 Cars, 1 Bus, 2 Two_Wheelers, 13 Adults, 142.2ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0006.jpg: 1216x1920 3 Light_Cars, 7 Cars, 2 SUVs, 1 Bus, 2 Two_Wheelers, 15 Adults, 142.6ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0007.jpg: 1216x1920 3 Light_Cars, 6 Cars, 1 SUV, 1 Bus, 2 Two_Wheelers, 16 Adults, 142.8ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0008.jpg: 1216x1920 3 Light_Cars, 6 Cars, 2 SUVs, 1 Bus, 2 Two_Wheelers, 16 Adults, 143.1ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0111/camera/camera_0/0009.jpg: 1216x1920 3 Light_Cars, 7 Cars, 1 Bus, 2 Two_Wheelers, 14 Adults, 146.6ms
# Speed: 2.1ms pre-process, 145.4ms inference, 1.6ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0111
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0111/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0112, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0000.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 7 Cars, 1 SUV, 1 Bus, 3 Two_Wheelers, 15 Adults, 157.8ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0001.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 6 Cars, 2 SUVs, 1 Bus, 2 Two_Wheelers, 14 Adults, 142.6ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0002.jpg: 1216x1920 2 Small_Cars, 2 Light_Cars, 5 Cars, 2 SUVs, 1 Bus, 2 Two_Wheelers, 14 Adults, 143.1ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0003.jpg: 1216x1920 2 Small_Cars, 2 Light_Cars, 5 Cars, 2 SUVs, 2 Two_Wheelers, 13 Adults, 143.9ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0004.jpg: 1216x1920 2 Small_Cars, 1 Light_Car, 5 Cars, 2 SUVs, 2 Two_Wheelers, 18 Adults, 144.1ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0005.jpg: 1216x1920 1 Small_Car, 2 Light_Cars, 6 Cars, 1 SUV, 1 Bus, 2 Two_Wheelers, 14 Adults, 144.6ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0006.jpg: 1216x1920 1 Small_Car, 1 Light_Car, 6 Cars, 2 SUVs, 1 Bus, 1 Two_Wheeler, 16 Adults, 146.1ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0007.jpg: 1216x1920 1 Small_Car, 1 Light_Car, 6 Cars, 1 SUV, 1 Bus, 2 Two_Wheelers, 16 Adults, 145.3ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0008.jpg: 1216x1920 2 Light_Cars, 7 Cars, 3 SUVs, 1 Bus, 2 Two_Wheelers, 13 Adults, 144.2ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0112/camera/camera_0/0009.jpg: 1216x1920 2 Small_Cars, 1 Light_Car, 8 Cars, 3 SUVs, 1 Bus, 2 Two_Wheelers, 14 Adults, 145.2ms
# Speed: 2.1ms pre-process, 145.7ms inference, 1.6ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_A_2210261635_0112
# 10 labels saved to runs/nia50_train1st/Suwon_A_2210261635_0112/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_A_2210261635_0113/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_A_2210261635_0113, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# ...
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0000.jpg: 1216x1920 5 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 210.4ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0001.jpg: 1216x1920 6 Cars, 1 Van, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 205.6ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0002.jpg: 1216x1920 5 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 216.9ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0003.jpg: 1216x1920 5 Cars, 1 Van, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 143.6ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0004.jpg: 1216x1920 4 Cars, 3 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 142.6ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0005.jpg: 1216x1920 6 Cars, 1 Van, 1 Medium_Truck, 1 Large_Truck, 1 Two_Wheeler, 3 Adults, 146.1ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0006.jpg: 1216x1920 5 Cars, 1 Van, 1 Small_Truck, 2 Medium_Trucks, 1 Two_Wheeler, 3 Adults, 144.2ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0007.jpg: 1216x1920 5 Cars, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 144.7ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0008.jpg: 1216x1920 6 Cars, 1 Van, 1 Medium_Truck, 1 Large_Truck, 1 Two_Wheeler, 3 Adults, 144.5ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0180/camera/camera_0/0009.jpg: 1216x1920 6 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 144.0ms
# Speed: 2.3ms pre-process, 164.3ms inference, 1.8ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_B_2211121422_0180
# 10 labels saved to runs/nia50_train1st/Suwon_B_2211121422_0180/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_B_2211121422_0181, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0000.jpg: 1216x1920 8 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 150.0ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0001.jpg: 1216x1920 6 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 142.9ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0002.jpg: 1216x1920 6 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 142.9ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0003.jpg: 1216x1920 6 Cars, 1 Van, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 144.3ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0004.jpg: 1216x1920 6 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 144.0ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0005.jpg: 1216x1920 6 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 143.6ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0006.jpg: 1216x1920 1 Small_Car, 5 Cars, 2 Vans, 3 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 144.2ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0007.jpg: 1216x1920 4 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 143.7ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0008.jpg: 1216x1920 1 Small_Car, 6 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 142.9ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0181/camera/camera_0/0009.jpg: 1216x1920 6 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 5 Adults, 143.9ms
# Speed: 2.4ms pre-process, 144.2ms inference, 1.3ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_B_2211121422_0181
# 10 labels saved to runs/nia50_train1st/Suwon_B_2211121422_0181/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_B_2211121422_0182, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0000.jpg: 1216x1920 6 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 148.9ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0001.jpg: 1216x1920 5 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 146.7ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0002.jpg: 1216x1920 5 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 145.2ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0003.jpg: 1216x1920 6 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 144.2ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0004.jpg: 1216x1920 5 Cars, 2 Vans, 3 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 3 Adults, 142.8ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0005.jpg: 1216x1920 7 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 146.6ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0006.jpg: 1216x1920 7 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 143.2ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0007.jpg: 1216x1920 7 Cars, 1 Van, 3 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 142.6ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0008.jpg: 1216x1920 7 Cars, 2 Vans, 4 SUVs, 1 Medium_Truck, 1 Large_Truck, 1 Bus, 1 Two_Wheeler, 4 Adults, 144.7ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0182/camera/camera_0/0009.jpg: 1216x1920 7 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 143.2ms
# Speed: 2.1ms pre-process, 144.8ms inference, 1.8ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_B_2211121422_0182
# 10 labels saved to runs/nia50_train1st/Suwon_B_2211121422_0182/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_B_2211121422_0183, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0000.jpg: 1216x1920 7 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Large_Truck, 1 Two_Wheeler, 5 Adults, 149.1ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0001.jpg: 1216x1920 7 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 142.2ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0002.jpg: 1216x1920 7 Cars, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 143.6ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0003.jpg: 1216x1920 1 Small_Car, 7 Cars, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 146.8ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0004.jpg: 1216x1920 1 Light_Car, 9 Cars, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 143.3ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0005.jpg: 1216x1920 1 Light_Car, 8 Cars, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 144.0ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0006.jpg: 1216x1920 8 Cars, 2 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 144.5ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0007.jpg: 1216x1920 9 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 146.4ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0008.jpg: 1216x1920 6 Cars, 3 SUVs, 1 Medium_Truck, 1 Two_Wheeler, 4 Adults, 144.7ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0183/camera/camera_0/0009.jpg: 1216x1920 6 Cars, 3 SUVs, 1 Medium_Truck, 1 Bus, 1 Two_Wheeler, 4 Adults, 145.9ms
# Speed: 2.1ms pre-process, 145.1ms inference, 1.8ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_B_2211121422_0183
# 10 labels saved to runs/nia50_train1st/Suwon_B_2211121422_0183/labels
# detect: weights=['/data/NIA50/kimgh/docker/yolov5/ckpt/nia50_bestweights_yolov5l6.pt'], source=/data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0, data=data/coco128.yaml, imgsz=[1200, 1920], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=0,1,2,3, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/nia50_train1st, name=Suwon_B_2211121422_0184, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de88 Python-3.10.8 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#                                                               CUDA:1 (Tesla T4, 15110MiB)
#                                                               CUDA:2 (Tesla T4, 15110MiB)
#                                                               CUDA:3 (Tesla T4, 15110MiB)
#
# Fusing layers...
# nia50_train1st_model_YOLOv5l6 summary: 267 layers, 46194438 parameters, 0 gradients, 107.9 GFLOPs
# WARNING ⚠️ --img-size [1200, 1920] must be multiple of max stride 32, updating to [1216, 1920]
# image 1/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0000.jpg: 1216x1920 7 Cars, 2 SUVs, 1 Medium_Truck, 1 Large_Truck, 1 Bus, 1 Two_Wheeler, 4 Adults, 148.6ms
# image 2/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0001.jpg: 1216x1920 7 Cars, 3 SUVs, 1 Medium_Truck, 1 Bus, 1 Two_Wheeler, 4 Adults, 142.0ms
# image 3/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0002.jpg: 1216x1920 8 Cars, 1 Van, 3 SUVs, 1 Medium_Truck, 1 Large_Truck, 2 Buss, 1 Two_Wheeler, 4 Adults, 142.8ms
# image 4/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0003.jpg: 1216x1920 6 Cars, 2 SUVs, 1 Medium_Truck, 2 Buss, 1 Two_Wheeler, 4 Adults, 143.9ms
# image 5/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0004.jpg: 1216x1920 9 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Bus, 1 Two_Wheeler, 5 Adults, 144.6ms
# image 6/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0005.jpg: 1216x1920 1 Small_Car, 7 Cars, 1 Van, 2 SUVs, 1 Medium_Truck, 1 Bus, 1 Two_Wheeler, 5 Adults, 143.9ms
# image 7/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0006.jpg: 1216x1920 1 Small_Car, 9 Cars, 1 Van, 1 SUV, 1 Medium_Truck, 1 Two_Wheeler, 5 Adults, 144.4ms
# image 8/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0007.jpg: 1216x1920 1 Small_Car, 8 Cars, 3 SUVs, 1 Medium_Truck, 1 Bus, 1 Two_Wheeler, 5 Adults, 146.7ms
# image 9/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0008.jpg: 1216x1920 7 Cars, 3 SUVs, 1 Medium_Truck, 1 Bus, 1 Two_Wheeler, 5 Adults, 142.4ms
# image 10/10 /data/NIA50/50-2/data/NIA50/train_1st/raw/Suwon_B_2211121422_0184/camera/camera_0/0009.jpg: 1216x1920 7 Cars, 1 Van, 1 Medium_Truck, 1 Large_Truck, 1 Bus, 1 Two_Wheeler, 5 Adults, 144.3ms
# Speed: 2.4ms pre-process, 144.4ms inference, 1.8ms NMS per image at shape (1, 3, 1216, 1920)
# Results saved to runs/nia50_train1st/Suwon_B_2211121422_0184
# 10 labels saved to runs/nia50_train1st/Suwon_B_2211121422_0184/labels

# %%
# %cd /data/NIA50/yolov5

path = '/content/drive/MyDrive/workspace/study/3D_Object_detection/OpenPCDet/data/kittimot/training/image_02'
folder_list = sorted(os.listdir(path))

for folder_name in folder_list[:1]:
    source_path = path + '/' + folder_name
    # !python detect.py --weights ./weights/yolo5s_kitti.pt --img 640 --conf 0.4 --source {source_path} --name {'train/' + folder_name} --data ./data/kitti.yaml \
        --save-txt --save-conf --exist-ok --device 0

# %%
# %cd /data/NIA50/yolov5

source_path = '/data/NIA50/data/2-050_sensor_sample/camera/front/images'

weights = '/data/NIA50/yolov5/runs/train/yolo_avill48_re/weights/best.pt'
data = '/data/NIA50/yolov5/nia50/yolo_aivill48/data_yolo_aivill48.yaml'

# !python detect.py --weights {weights} --img 960 1280 --conf 0.4 --source {source_path} --name sample_yolo_avill48_re --data {data} \
        --save-txt --save-conf --exist-ok --device 0,1,2,3

# %%
# %cd /data/NIA50/50-2/models/yolov5

weights = '/data/NIA50/50-2/models/yolov5/runs/train/nia50_train1st3/weights/best.pt'
img_size = '1200 1920'
source_path = '/data/NIA50/50-2/data/NIA50/train_1st/yolov5/ImageSets'
data = '/data/NIA50/50-2/data/NIA50/train_1st/yolov5/nia50_train1st_data_yolov5l6.yaml'
name = 'nia50_train1st'

# !python detect.py --weights {weights} --conf 0.4 --source {source_path} --data {data} --name {name} \
        --save-txt --save-conf --exist-ok --device 0,1,2,3

# %%
# %cd /data/NIA50/50-2/models/yolov5

source_path = '/data/NIA50/SUSTechPOINTS_2-050/data/Suwon_A_2210261635_0001_calib_ok/camera/camera_0'
weights = '/data/NIA50/50-2/models/yolov5/ckpt/yolov5l6.pt'
img_size = '1200 1920'
name = 'NIA50_test'

# !python detect.py --weights {weights} --img {img_size} --conf 0.4 --source {source_path} --name {name} --classes 0 1 2 3 5 6 7 \
        --save-txt --save-conf --exist-ok --device 0,1,2

# %%
# %cd /data/NIA50/50-2/models/yolov5

# !python detect.py --help
# Out:
# /data/NIA50/50-2/models/yolov5
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE]
#                  [--data DATA] [--imgsz IMGSZ [IMGSZ ...]]
#                  [--conf-thres CONF_THRES] [--iou-thres IOU_THRES]
#                  [--max-det MAX_DET] [--device DEVICE] [--view-img]
#                  [--save-txt] [--save-conf] [--save-crop] [--nosave]
#                  [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                  [--augment] [--visualize] [--update] [--project PROJECT]
#                  [--name NAME] [--exist-ok] [--line-thickness LINE_THICKNESS]
#                  [--hide-labels] [--hide-conf] [--half] [--dnn]
#                  [--vid-stride VID_STRIDE]
#
# options:
#   -h, --help            show this help message and exit
#   --weights WEIGHTS [WEIGHTS ...]
#                         model path or triton URL
#   --source SOURCE       file/dir/URL/glob/screen/0(webcam)
#   --data DATA           (optional) dataset.yaml path
#   --imgsz IMGSZ [IMGSZ ...], --img IMGSZ [IMGSZ ...], --img-size IMGSZ [IMGSZ ...]
#                         inference size h,w
#   --conf-thres CONF_THRES
#                         confidence threshold
#   --iou-thres IOU_THRES
#                         NMS IoU threshold
#   --max-det MAX_DET     maximum detections per image
#   --device DEVICE       cuda device, i.e. 0 or 0,1,2,3 or cpu
#   --view-img            show results
#   --save-txt            save results to *.txt
#   --save-conf           save confidences in --save-txt labels
#   --save-crop           save cropped prediction boxes
#   --nosave              do not save images/videos
#   --classes CLASSES [CLASSES ...]
#                         filter by class: --classes 0, or --classes 0 2 3
#   --agnostic-nms        class-agnostic NMS
#   --augment             augmented inference
#   --visualize           visualize features
#   --update              update all models
#   --project PROJECT     save results to project/name
#   --name NAME           save results to project/name
#   --exist-ok            existing project/name ok, do not increment
#   --line-thickness LINE_THICKNESS
#                         bounding box thickness (pixels)
#   --hide-labels         hide labels
#   --hide-conf           hide confidences
#   --half                use FP16 half-precision inference
#   --dnn                 use OpenCV DNN for ONNX inference
#   --vid-stride VID_STRIDE
#                         video frame-rate stride

# %% [markdown]
# ## # 프레임 라벨 하나로 합치기
# ---

# %%
# import glob
# from sklearn.model_selection import train_test_split

# img_list = sorted(glob.glob('/data/hwang/datasets/kitti/training/images/*.png'))

# train_list, val_list = train_test_split(img_list, test_size = 0.2, random_state = 0)

# with open('/home/ubuntu/kimgh/yolov5/kitti_yaml/train.txt', 'w') as f:
#     f.write('\n'.join(train_list) + '\n')
    
# with open('/home/ubuntu/kimgh/yolov5/kitti_yaml/val.txt', 'w') as f:
#     f.write('\n'.join(val_list) + '\n')

    
# # with open('')

# %%
import pandas as pd
import re
import os

label_path = '/content/drive/MyDrive/workspace/study/3D_Object_detection/yolov5/runs/detect/train/0000/labels/'
frame_list = sorted(os.listdir(label_path))

label_df = pd.DataFrame()
for frame in frame_list:
    frame_num = int(re.search('[0-9]*', frame)[0])
    frame_df = pd.read_csv(label_path + frame, header = None, sep = ' ').replace(0, f'{frame_num}', regex = True)
    # frame_df = frame_df.replace(' ', ',', regex = True)

    label_df = pd.concat((label_df, frame_df), axis = 0)

label_df.to_csv('/content/drive/MyDrive/workspace/study/3D_Object_detection/yolov5/runs/detect/train/0000/0000.txt', index = None, header = None, sep = ',')

# %% [markdown]
# # # 로컬에서 모델 로드
# ---

# %%
import cv2
import torch
import io
from PIL import Image

# %%
# !pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %%
weights = '/content/drive/MyDrive/workspace/study/3D_Object_detection/yolov5/weights/yolo5s_kitti.pt'

# model = torch.hub.load('ultralystics/yolov5', 'yolov5s') # 깃에서 직접 불러오기
model = torch.hub.load('/content/drive/MyDrive/workspace/study/3D_Object_detection/yolov5', 'custom', path = weights, source = 'local') # 로컬에서 불러오기

# %%
path = '/content/drive/MyDrive/workspace/study/3D_Object_detection/OpenPCDet/data/kittimot/training/image_02'
folder_list = sorted(os.listdir(path))

img = path + '/' + folder_list[0] + '/000000.png'

# %%
results = model(img)

# %%
df = results.pandas().xyxy[0]
df

# %%
a = df.iloc[0][:4].values.astype('float')
list(a)

# %%
import numpy as np

a = np.array([554, 791, 605, 884]) / 1.6
a = np.array([554, 776, 749, 879]) / 1.6
a = np.array([871, 862, 1180, 956]) / 1.6
# a = np.array([1494, 801, 1883, 909]) / 1.6

# %%
img = '/data/project50/1-cycle/camera/rear/1639543825.777566671.jpg'
img_.size

# %%
from PIL import Image, ImageDraw, ImageFont

img_ = Image.open(img).convert('RGB')

color = (0,255,0)

font_size = 15
# font = ImageFont.truetype('/content/drive/MyDrive/workspace/study/3D_Object_detection/yolov5/fonts/arial.ttf', 25) # arial.ttf 글씨체, font_size=15
font = ImageFont.load_default()
# box_color_RGBA  = (0,255,0,255)
# fill_color_RGBA = (0,255,0,50)
# draw = ImageDraw.Draw(img_, 'RGBA') # RGBA
# draw.rectangle((100,100,300,300), outline=box_color_RGBA, fill=fill_color_RGBA, width = 3)
# img_.show()

draw = ImageDraw.Draw(img_)
text_pos = (a[0], a[1]-27)
# draw.text(text_pos, f"{df['name'][0], round(df['confidence'][0], 2)}", fill = color, font = font, stroke_width = 1)
draw.rectangle(list(a), outline = color, width = 3)
# img_.show()

img_
